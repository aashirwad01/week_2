# %% [markdown]
# ## DATA VISUALISATION ON IPL DATASET

# %%
import pandas as pd
import numpy as np

# %%
dl=pd.read_csv('deliveries.csv')
mth=pd.read_csv('matches.csv')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %% [markdown]
# ## IPL dataset by merging matches and deliveries datasets together

# %%
s_data=mth[['id','season','winner']]

ipl=dl.merge(s_data,how='inner',left_on='match_id',right_on='id')

# %%
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  penalty_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...             0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...             0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...             0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...             0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...             0
#
# ...

# %% [markdown]
# ## seasonwise total runs made division by type of run made

# %%
ipl_s=ipl.groupby('season')

# %%
ipl_s['total_runs'].value_counts()
# Out:
# season  total_runs
# 2008    1             5337
#         0             4916
#         4             1726
#         2              796
#         6              618
#         3               47
#         5               44
#         7                5
# 2009    1             5493
#         0             5119
#         4             1341
#         2             1049
#         6              504
#         3               67
#         5               29
#         7                4
# 2010    1             6120
#         0             4996
#         4             1729
#         2              961
#         6              585
#         3               62
#         5               43
#         7                2
# 2011    1             6944
#         0             6282
#         4             1950
#         2             1101
#         6              634
#         3               58
#                       ...
# 2014    4             1591
#         2             1058
# ...

# %%
type(ipl_s['total_runs'].value_counts())
# Out:
# pandas.core.series.Series

# %%
#sns.lineplot(x=ipl_s['season'].value_counts(),y=ipl_s['total_runs'].value_counts(),data=ipl_s)

# %%
#sns.catplot(x='season',y=None,hue='total_runs',data=ipl)

# %%
plt.figure(figsize=(20,20))
sns.countplot(x='season',y=None,hue='total_runs',data=ipl)

# %% [markdown]
# ## sum of total runs made

# %%
ipl_s['total_runs'].sum()
# Out:
# season
# 2008    17937
# 2009    16353
# 2010    18883
# 2011    21154
# 2012    22453
# 2013    22602
# 2014    18931
# 2015    18353
# 2016    18862
# 2017    18786
# Name: total_runs, dtype: int64

# %%
sns.countplot(x='season',hue='total_runs',data=ipl)

# %%
#plt.figure(figsize=(40,40))
sns.lineplot(data=ipl_s['total_runs'].sum())

# %%
type(ipl_s['total_runs'].sum())
# Out:
# pandas.core.series.Series

# %%
#ipl[(ipl['season']==2017)]['total_runs'].value_counts()

# %%
#ipl[(ipl['season']==2017)]['total_runs']

# %%
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  penalty_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...             0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...             0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...             0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...             0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...             0
#
# ...

# %%
#sns.relplot(x=ipl[['season']],y=ipl[['total_runs']],data=ipl);

# %%
plt.figure(figsize=(500,40))
plt.title('batsman wise total runs')
sns.barplot(x=dl.batsman,y=dl['total_runs'])
plt.ylabel('total runs each ball')
# Out:
# Text(0, 0.5, 'total runs each ball')

# %%
n_mth=mth.drop(['umpire3'],axis=1)
n_mth
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %% [markdown]
# ## venue wise win by wickets

# %%
plt.figure(figsize=(100,40))
sns.barplot(x=n_mth['win_by_wickets'],y=mth.city)

# %% [markdown]
# ## venue wise total no of matches played at each venue....

# %%
mth_city=mth.groupby('city')
mth_city.count().sort_values('id',ascending=False)['id']
plt.figure(figsize=(40,40))
sns.lineplot(data=mth_city.count().sort_values('id',ascending=False)[['id']])

# %%
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  penalty_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...             0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...             0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...             0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...             0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...             0
#
# ...

# %%
mth['city'].value_counts()
# Out:
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Abu Dhabi          7
# Cuttack            7
# Ranchi             7
# Port Elizabeth     7
# Sharjah            6
# Raipur             6
# Indore             5
# Kochi              5
# Kanpur             4
# East London        3
# Nagpur             3
# Kimberley          3
# Bloemfontein       2
# Name: city, dtype: int64

# %%
ipl.shape
# Out:
# (150460, 24)

# %%
ipl_ww=ipl[(ipl['winner'].notnull())]

# %%
ipl_ww.shape
# Out:
# (150139, 24)

# %%
#plt.figure(figsize=(400,40))
#sns.heatmap(x='batting_team',y='winner',data=ipl_ww)

# %% [markdown]
# ## 2017 venuewise win by runs scatter plot

# %%
mth_city=mth.groupby('city')

# %%
mth_city.head()
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
pltdf=mth[(mth['season']==2017)]

# %%
pltdf[(pltdf['win_by_runs']!=0)]
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 13  14    2017     Kolkata  2017-04-15        Kolkata Knight Riders
# 14  15    2017       Delhi  2017-04-15             Delhi Daredevils
# 16  17    2017   Bangalore  2017-04-16       Rising Pune Supergiant
# 18  19    2017   Hyderabad  2017-04-17          Sunrisers Hyderabad
# 19  20    2017      Rajkot  2017-04-18  Royal Challengers Bangalore
# 20  21    2017   Hyderabad  2017-04-19          Sunrisers Hyderabad
# 23  24    2017      Mumbai  2017-04-22               Mumbai Indians
# 25  26    2017      Rajkot  2017-04-23              Kings XI Punjab
# 26  27    2017     Kolkata  2017-04-23        Kolkata Knight Riders
# 27  28    2017      Mumbai  2017-04-24       Rising Pune Supergiant
# ...

# %%
type(pltdf)
# Out:
# pandas.core.frame.DataFrame

# %%
k=pltdf[(pltdf['win_by_runs']!=0)][['win_by_runs','win_by_wickets','season','city']]

# %%
k
# Out:
#     win_by_runs  win_by_wickets  season        city
# 0            35               0    2017   Hyderabad
# 4            15               0    2017   Bangalore
# 8            97               0    2017        Pune
# 13           17               0    2017     Kolkata
# 14           51               0    2017       Delhi
# 16           27               0    2017   Bangalore
# 18            5               0    2017   Hyderabad
# 19           21               0    2017      Rajkot
# 20           15               0    2017   Hyderabad
# 23           14               0    2017      Mumbai
# 25           26               0    2017      Rajkot
# 26           82               0    2017     Kolkata
# 27            3               0    2017      Mumbai
# 31           26               0    2017  Chandigarh
# 32           61               0    2017        Pune
# 35           48               0    2017   Hyderabad
# 41           19               0    2017   Bangalore
# ...

# %%
type(pltdf[['win_by_runs','win_by_wickets','season','city']])
# Out:
# pandas.core.frame.DataFrame

# %%
sns.relplot(x='win_by_runs',size='win_by_runs', sizes=(50, 500),y='city',data=k);

# %% [markdown]
# ## venuewise 2017 win by wickets

# %%
ww=pltdf[(pltdf['win_by_wickets']!=0)][['win_by_runs','win_by_wickets','season','city']]

# %%
ww
# Out:
#     win_by_runs  win_by_wickets  season        city
# 1             0               7    2017        Pune
# 2             0              10    2017      Rajkot
# 3             0               6    2017      Indore
# 5             0               9    2017   Hyderabad
# 6             0               4    2017      Mumbai
# 7             0               8    2017      Indore
# 9             0               4    2017      Mumbai
# 10            0               8    2017     Kolkata
# 11            0               4    2017   Bangalore
# 12            0               7    2017      Rajkot
# 15            0               6    2017      Mumbai
# 17            0               4    2017       Delhi
# 21            0               8    2017      Indore
# 22            0               4    2017     Kolkata
# 24            0               6    2017        Pune
# 28            0               7    2017        Pune
# 29            0               7    2017   Bangalore
# ...

# %%
sns.relplot(x='win_by_wickets',y='city',hue='win_by_wickets', size="win_by_wickets", sizes=(15, 200),data=ww);

# %%
mth_city.head()
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
ipl_s.head()
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0              1       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1    Sunrisers Hyderabad  Royal Challengers Bangalore
# 13862         60       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 13863         60       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 13864         60       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 13865         60       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 13866         60       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 27351        118       1         Mumbai Indians          Chennai Super Kings
# ...

# %%
#dl[(dl['batting_team']=='Sunrisers Hyderabad')][['batsman','bowling_team','batting_team']]

# %% [markdown]
# ## total bye runs made

# %%
dl[(dl['bye_runs']!=0)]['bye_runs'].value_counts()
# Out:
# 1    285
# 4     97
# 2     28
# 3      2
# Name: bye_runs, dtype: int64

# %%
sns.lineplot(data=dl[(dl['bye_runs']!=0)]['bye_runs'].value_counts())

# %% [markdown]
# ## venue wise total matches played

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=80)
sns.countplot(x='venue',data=mth)

# %% [markdown]
# ## relation between toss winner and winner

# %%
plt.xticks(rotation=80)
sns.scatterplot(y='winner',x='toss_winner',data=mth)

# %% [markdown]
# ## season wise toss decisions

# %%
mth['win']=np.where(mth['win_by_runs']>0,'chose Bat',' chose Bowl')

mth['win'].value_counts()
# Out:
#  chose Bowl    349
# chose Bat      287
# Name: win, dtype: int64

# %%
sns.countplot('season',hue='win',data=mth)

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation=90)


sns.countplot('venue',hue='win',data=mth)

# %% [markdown]
# ## runs made by individual player over 100 deliveries here DA Warner

# %%
plt.figure(figsize=(10,10))
plt.title('DA Warner ')

#plt.figure(figsize=(15,15))
sns.scatterplot(size='total_runs',sizes=(15,50),data=dl[(dl['batsman']=='DA Warner')][['total_runs','bye_runs','penalty_runs','extra_runs']].head(100))
plt.xlabel('Delivery no')
# Out:
# Text(0.5, 0, 'Delivery no')

# %%
#dl.head(30)

# %%
sns.jointplot(x='match_id',y='total_runs',data=dl[(dl['batsman']=='DA Warner')],kind='hex')

# %%
plt.title('DA Warner ')
sns.catplot(data=dl[(dl['batsman']=='DA Warner')][['total_runs','bye_runs','penalty_runs','extra_runs']].head(100))
plt.xlabel('Delivery no')
# Out:
# Text(0.5, 5.89374999999999, 'Delivery no')

# %%
sns.lineplot(data=mth[['win_by_wickets','season','team1','team2']].sort_values('win_by_wickets',ascending=False)['win_by_wickets'].value_counts().drop(0))

# %% [markdown]
# ## season wise team performances

# %%
mth.groupby('season')['winner'].value_counts()
# Out:
# season  winner
# 2008    Rajasthan Royals               13
#         Kings XI Punjab                10
#         Chennai Super Kings             9
#         Delhi Daredevils                7
#         Mumbai Indians                  7
#         Kolkata Knight Riders           6
#         Royal Challengers Bangalore     4
#         Deccan Chargers                 2
# 2009    Delhi Daredevils               10
#         Deccan Chargers                 9
#         Royal Challengers Bangalore     9
#         Chennai Super Kings             8
#         Kings XI Punjab                 7
#         Rajasthan Royals                6
#         Mumbai Indians                  5
#         Kolkata Knight Riders           3
# 2010    Mumbai Indians                 11
#         Chennai Super Kings             9
#         Deccan Chargers                 8
#         Royal Challengers Bangalore     8
#         Delhi Daredevils                7
#         Kolkata Knight Riders           7
# ...

# %%
plt.figure(figsize=(15,15))
plt.title('Season wise team performances')
plt.xticks(rotation=90)
sns.countplot(x='season',hue='winner',data=mth)

# %% [markdown]
# ## city wise winners

# %%
plt.figure(figsize=(10,10))
plt.title('Season wise team performances')
plt.xticks(rotation=90)
sns.countplot(hue='city',x='winner',data=mth)

# %% [markdown]
# ## venues used each season

# %%
plt.figure(figsize=(15,15))
plt.title('Season wise team performances')
plt.xticks(rotation=90)
sns.countplot(hue='venue',x='season',data=mth)

# %% [markdown]
# ## winner teams performance analysis

# %%
plt.figure(figsize=(15,15))
plt.title('winner teams performance analysis')
plt.xticks(rotation=90)
sns.countplot(x='total_runs',hue='winner',data=ipl)

# %%
#sns.PairGrid(mth)

# %% [markdown]
# ## total runs made over matches

# %%
#plt.figure(figsize=(150,150))
sns.catplot(y='match_id',x='total_runs',data=ipl)

# %% [markdown]
# ## teamwise player of matches list graph

# %%
plt.xticks(rotation=90)
sns.countplot(hue='player_of_match',x='winner',data=mth)

# %% [markdown]
# ## umpires in win of various teams

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation=90)
sns.countplot(x='umpire2',hue='winner',data=mth)
